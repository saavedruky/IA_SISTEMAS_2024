# %% [markdown]
# <a href="https://colab.research.google.com/github/saavedruky/IA_SISTEMAS_2024/blob/main/Ropa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.8-dev python3.8-venv -y

# !python3.8 -m venv tfjs-venv

# !source tfjs-vfjs-venv/bin/activate
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.8-dev is already the newest version (3.8.20-1+jammy1).
# python3.8-venv is already the newest version (3.8.20-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 56 not upgraded.
# /bin/bash: line 1: tfjs-vfjs-venv/bin/activate: No such file or directory

# %%
# !tfjs-venv/bin/pip install --upgrade pip
# !tfjs-venv/bin/pip install tensorflow==2.8 tensorflowjs

# !pip install tensorflow-decision-forests --upgrade
# Out:
# Requirement already satisfied: pip in ./tfjs-venv/lib/python3.8/site-packages (24.3.1)
# Requirement already satisfied: tensorflow==2.8 in ./tfjs-venv/lib/python3.8/site-packages (2.8.0)
# Requirement already satisfied: tensorflowjs in ./tfjs-venv/lib/python3.8/site-packages (3.21.0)
# Requirement already satisfied: absl-py>=0.4.0 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (3.11.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (1.24.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (3.4.0)
# Requirement already satisfied: protobuf>=3.9.2 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (3.19.6)
# Requirement already satisfied: setuptools in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (56.0.0)
# Requirement already satisfied: six>=1.12.0 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (1.16.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (2.8.0.dev2021122109)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflow==2.8) (1.67.1)
# Requirement already satisfied: flax>=0.5.3 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflowjs) (0.7.2)
# Requirement already satisfied: importlib_resources>=5.9.0 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflowjs) (6.4.5)
# Requirement already satisfied: jax>=0.3.16 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflowjs) (0.4.13)
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflowjs) (0.12.0)
# Requirement already satisfied: packaging~=20.9 in ./tfjs-venv/lib/python3.8/site-packages (from tensorflowjs) (20.9)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./tfjs-venv/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow==2.8) (0.44.0)
# Requirement already satisfied: msgpack in ./tfjs-venv/lib/python3.8/site-packages (from flax>=0.5.3->tensorflowjs) (1.1.0)
# Requirement already satisfied: optax in ./tfjs-venv/lib/python3.8/site-packages (from flax>=0.5.3->tensorflowjs) (0.1.8)
# Requirement already satisfied: orbax-checkpoint in ./tfjs-venv/lib/python3.8/site-packages (from flax>=0.5.3->tensorflowjs) (0.2.3)
# Requirement already satisfied: tensorstore in ./tfjs-venv/lib/python3.8/site-packages (from flax>=0.5.3->tensorflowjs) (0.1.45)
# Requirement already satisfied: rich>=11.1 in ./tfjs-venv/lib/python3.8/site-packages (from flax>=0.5.3->tensorflowjs) (13.9.4)
# Requirement already satisfied: PyYAML>=5.4.1 in ./tfjs-venv/lib/python3.8/site-packages (from flax>=0.5.3->tensorflowjs) (6.0.2)
# Requirement already satisfied: zipp>=3.1.0 in ./tfjs-venv/lib/python3.8/site-packages (from importlib_resources>=5.9.0->tensorflowjs) (3.20.2)
# Requirement already satisfied: ml-dtypes>=0.1.0 in ./tfjs-venv/lib/python3.8/site-packages (from jax>=0.3.16->tensorflowjs) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in ./tfjs-venv/lib/python3.8/site-packages (from jax>=0.3.16->tensorflowjs) (1.10.1)
# Requirement already satisfied: importlib-metadata>=4.6 in ./tfjs-venv/lib/python3.8/site-packages (from jax>=0.3.16->tensorflowjs) (8.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in ./tfjs-venv/lib/python3.8/site-packages (from packaging~=20.9->tensorflowjs) (3.1.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./tfjs-venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in ./tfjs-venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in ./tfjs-venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in ./tfjs-venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in ./tfjs-venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in ./tfjs-venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in ./tfjs-venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./tfjs-venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./tfjs-venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./tfjs-venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./tfjs-venv/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./tfjs-venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./tfjs-venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./tfjs-venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./tfjs-venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./tfjs-venv/lib/python3.8/site-packages (from rich>=11.1->flax>=0.5.3->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./tfjs-venv/lib/python3.8/site-packages (from rich>=11.1->flax>=0.5.3->tensorflowjs) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./tfjs-venv/lib/python3.8/site-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.1.5)
# Requirement already satisfied: chex>=0.1.7 in ./tfjs-venv/lib/python3.8/site-packages (from optax->flax>=0.5.3->tensorflowjs) (0.1.7)
# Requirement already satisfied: jaxlib>=0.1.37 in ./tfjs-venv/lib/python3.8/site-packages (from optax->flax>=0.5.3->tensorflowjs) (0.4.13)
# Requirement already satisfied: cached_property in ./tfjs-venv/lib/python3.8/site-packages (from orbax-checkpoint->flax>=0.5.3->tensorflowjs) (2.0.1)
# Requirement already satisfied: etils in ./tfjs-venv/lib/python3.8/site-packages (from orbax-checkpoint->flax>=0.5.3->tensorflowjs) (1.3.0)
# Requirement already satisfied: nest_asyncio in ./tfjs-venv/lib/python3.8/site-packages (from orbax-checkpoint->flax>=0.5.3->tensorflowjs) (1.6.0)
# Requirement already satisfied: dm-tree>=0.1.5 in ./tfjs-venv/lib/python3.8/site-packages (from chex>=0.1.7->optax->flax>=0.5.3->tensorflowjs) (0.1.8)
# Requirement already satisfied: toolz>=0.9.0 in ./tfjs-venv/lib/python3.8/site-packages (from chex>=0.1.7->optax->flax>=0.5.3->tensorflowjs) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./tfjs-venv/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.5.3->tensorflowjs) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./tfjs-venv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./tfjs-venv/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.2)
# Requirement already satisfied: tensorflow-decision-forests in /usr/local/lib/python3.10/dist-packages (1.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests) (2.2.2)
# Requirement already satisfied: tensorflow==2.18.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests) (2.18.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests) (1.16.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests) (1.4.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests) (0.44.0)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests) (3.1.1)
# Requirement already satisfied: tf-keras~=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests) (2.18.0)
# Requirement already satisfied: ydf in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests) (0.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (75.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (1.64.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (3.6.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow-decision-forests) (0.37.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow-decision-forests) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow-decision-forests) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow-decision-forests) (2024.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow==2.18.0->tensorflow-decision-forests) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow==2.18.0->tensorflow-decision-forests) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow==2.18.0->tensorflow-decision-forests) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->tensorflow-decision-forests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->tensorflow-decision-forests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->tensorflow-decision-forests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->tensorflow-decision-forests) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->tensorflow-decision-forests) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->tensorflow-decision-forests) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->tensorflow-decision-forests) (3.0.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow==2.18.0->tensorflow-decision-forests) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.5.0->tensorflow==2.18.0->tensorflow-decision-forests) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.5.0->tensorflow==2.18.0->tensorflow-decision-forests) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow==2.18.0->tensorflow-decision-forests) (0.1.2)

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = "1"

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
datos, metadatos = tfds.load('fashion_mnist', as_supervised=True, with_info=True)

# %%
metadatos
# Out:
# tfds.core.DatasetInfo(
#     name='fashion_mnist',
#     full_name='fashion_mnist/3.0.1',
#     description="""
#     Fashion-MNIST is a dataset of Zalando's article images consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes.
#     """,
#     homepage='https://github.com/zalandoresearch/fashion-mnist',
#     data_dir='/root/tensorflow_datasets/fashion_mnist/3.0.1',
#     file_format=tfrecord,
#     download_size=29.45 MiB,
#     dataset_size=36.42 MiB,
#     features=FeaturesDict({
#         'image': Image(shape=(28, 28, 1), dtype=uint8),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=10),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=10000, num_shards=1>,
#         'train': <SplitInfo num_examples=60000, num_shards=1>,
#     },
#     citation="""@article{DBLP:journals/corr/abs-1708-07747,
#       author    = {Han Xiao and
#                    Kashif Rasul and
#                    Roland Vollgraf},
#       title     = {Fashion-MNIST: a Novel Image Dataset for Benchmarking Machine Learning
#                    Algorithms},
#       journal   = {CoRR},
#       volume    = {abs/1708.07747},
#       year      = {2017},
#       url       = {http://arxiv.org/abs/1708.07747},
#       archivePrefix = {arXiv},
#       eprint    = {1708.07747},
#       timestamp = {Mon, 13 Aug 2018 16:47:27 +0200},
#       biburl    = {https://dblp.org/rec/bib/journals/corr/abs-1708-07747},
#       bibsource = {dblp computer science bibliography, https://dblp.org}
#     }""",
# )

# %%
datos_entrenamiento, datos_pruebas = datos['train'], datos['test']

# %%
nombres_clases = metadatos.features['label'].names

# %%
nombres_clases
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
def normalizar(imagenes, etiquetas):
  imagenes = tf.cast(imagenes, tf.float32)
  imagenes /= 255
  return imagenes, etiquetas

  datos_entrenamiento = datos_entrenamiento.map(normalizar)
  datos_pruebas = datos_pruebas.map(normalizar)

  datos_entrenamiento = datos_entrenamiento.cache()
  datos_pruebas = datos_pruebas.cache()

# %%
for imagen, etiqueta in datos_entrenamiento.take(1):
  break
imagen = imagen.numpy().reshape((28,28))

import matplotlib.pyplot as plt

plt.figure()
plt.imshow(imagen, cmap=plt.cm.binary)
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(10,10))
for i, (imagen, etiqueta) in enumerate(datos_entrenamiento.take(25)):
  imagen = imagen.numpy().reshape((28,28))
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(imagen, cmap=plt.cm.binary)
  plt.xlabel(nombres_clases[etiqueta])
plt.show()

# %%
modelo = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(50, activation=tf.nn.relu),
    tf.keras.layers.Dense(50, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
modelo.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# %%
num_ej_entrenamiento = metadatos.splits["train"].num_examples
num_ej_pruebas = metadatos.splits["test"].num_examples

# %%
print(num_ej_entrenamiento)
print(num_ej_pruebas)
# Out:
# 60000
# 10000

# %%
TAMANO_LOTE = 32

# %%
datos_entrenamiento = datos_entrenamiento.repeat().shuffle(num_ej_entrenamiento).batch(TAMANO_LOTE)
datos_pruebas = datos_pruebas.batch(TAMANO_LOTE)

# %%
import math

historial = modelo.fit(datos_entrenamiento, epochs=5, steps_per_epoch=math.ceil(num_ej_entrenamiento/TAMANO_LOTE))

plt.xlabel("# Epoca")
plt.ylabel("Magnitud de pérdida")
plt.plot(historial.history["loss"])
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 17s 2ms/step - loss: 1.5812 - accuracy: 0.6725
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7019 - accuracy: 0.7357
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6510 - accuracy: 0.7560
# Epoch 4/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6344 - accuracy: 0.7618
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5997 - accuracy: 0.7711

# %%
import numpy as np

for imagenes_prueba, etiquetas_prueba in datos_pruebas.take(1):
  imagenes_prueba = imagenes_prueba.numpy()
  etiquetas_prueba = etiquetas_prueba.numpy()
  predicciones = modelo.predict(imagenes_prueba)
##----------------------
  def graficar_imagen(i, predicciones_array, etiquetas_reales, imagenes):
   arr_predicciones, etiqueta_real, img = predicciones_array[i], etiquetas_reales[i], imagenes[i]
   plt.grid(False)
   plt.xticks([])
   plt.yticks([])
   plt.imshow(img[...,0], cmap=plt.cm.binary)

   etiqueta_prediccion = np.argmax(arr_predicciones)
   if etiqueta_prediccion == etiqueta_real:
    color = "blue"
   else:
    color = "red"

##----------------------
   plt.xlabel("{} {:2.0f}% ({})".format(nombres_clases[etiqueta_prediccion],
                                100*np.max(arr_predicciones),
                                nombres_clases[etiqueta_real]),
                                color=color)

def graficar_valor_arreglo(i, arr_predicciones, etiqueta_real):
    arr_predicciones, etiqueta_real = arr_predicciones[i], etiqueta_real[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    grafica = plt.bar(range(10), arr_predicciones, color="#777777")
    plt.ylim([0,1])
    etiqueta_prediccion = np.argmax(arr_predicciones)

##--------------------

filas = 5
columnas = 5
num_imagenes = filas*columnas
plt.figure(figsize=(2*2*columnas, 2*filas))
for i in range(num_imagenes):
  plt.subplot(filas, 2*columnas, 2*i+1)
  graficar_imagen(i, predicciones, etiquetas_prueba, imagenes_prueba)
  plt.subplot(filas, 2*columnas, 2*i+2)
  graficar_valor_arreglo(i, predicciones, etiquetas_prueba)
# Out:
# 1/1 [==============================] - 0s 60ms/step

# %%
imagen = imagenes_prueba[4]
imagen = np.array([imagen])
prediccion = modelo.predict(imagen)

print("Prediccion: "+nombres_clases[np.argmax(prediccion[0])])
# Out:
# 1/1 [==============================] - 0s 63ms/step
# Prediccion: Sandal

# %%
# !mkdir clasificacion

modelo.save('clasificacionropa.h5')

# !tensorflowjs_converter --input_format=keras clasificacionropa.h5 clasificacion
# Out:
# mkdir: cannot create directory ‘clasificacion’: File exists
# 2024-11-04 23:47:21.892513: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1730764041.917926   10747 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1730764041.925514   10747 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 🌲 Try https://ydf.readthedocs.io, the successor of TensorFlow Decision Forests with more features and faster training!
